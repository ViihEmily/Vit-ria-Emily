# %% [markdown]
# Perguntas a serem respondidas:
# 1 - Quais os produtos mais vendidos considerando os últimos 3 anos? 2- Qual o produto mais caro e o mais barato? 3- Qual a categoria de produto mais vendida e menos vendida? Qual a categoria menos e mais cara? 4- Qual o produto com melhor e pior NPS?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Ecommerce_DBS.csv')

# %%
df.head()
# Out:
#    Customer ID Purchase Date Product Category  Product Price  Quantity  \
# 0        46251    08/09/2020      Electronics             12         3
# 1        46251    05/03/2022             Home            468         4
# 2        46251    23/05/2022             Home            288         2
# 3        46251    12/11/2020         Clothing            196         1
# 4        13593    27/11/2020             Home            449         1
#
#    Total Purchase Amount  NPS  Customer Age   Gender             Source  \
# 0                    740    7             20    Male  Instagram Campign
# 1                   2739    8             20    Male  Instagram Campign
# 2                   3196   10             20    Male                SEM
# 3                   3509    3             20    Male  Instagram Campign
# 4                   3452    3             20  Female  Instagram Campign
#
#          Country         State   Latitude  Longituide
# ...

# %%
df.tail()
# Out:
#         Customer ID Purchase Date Product Category  Product Price  Quantity  \
# 249995        33308    10/08/2023         Clothing            279         2
# 249996        48835    23/11/2021             Home             27         1
# 249997        21019    02/07/2020             Home             17         5
# 249998        49234    30/12/2020            Books            398         2
# 249999        16971    13/03/2021      Electronics            425         4
#
#         Total Purchase Amount  NPS  Customer Age   Gender             Source  \
# 249995                   2187    1             55    Male                SEM
# 249996                   3615    1             42  Female  Instagram Campign
# 249997                   2466    0             41    Male  Instagram Campign
# 249998                   3668    8             34  Female  Instagram Campign
# 249999                   2370    2             36  Female     Organic Search
#
# ...

# %%
df.nunique()
# Out:
# Customer ID              49673
# Purchase Date             1354
# Product Category             4
# Product Price              491
# Quantity                     5
# Total Purchase Amount     5247
# NPS                         11
# Customer Age                53
# Gender                       2
# Source                       4
# Country                      2
# State                       19
# Latitude                    17
# Longituide                  17
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   NPS                    250000 non-null  int64
#  7   Customer Age           250000 non-null  int64
#  8   Gender                 250000 non-null  object
#  9   Source                 250000 non-null  object
#  10  Country                250000 non-null  object
#  11  State                  250000 non-null  object
#  12  Latitude               250000 non-null  float64
#  13  Longituide             250000 non-null  float64
# ...

# %%
df.describe()
# Out:
#         Customer ID  Product Price       Quantity  Total Purchase Amount  \
# count  250000.00000  250000.000000  250000.000000          250000.000000
# mean    25004.03624     254.659512       2.998896            2725.370732
# std     14428.27959     141.568577       1.414694            1442.933565
# min         1.00000      10.000000       1.000000             100.000000
# 25%     12497.75000     132.000000       2.000000            1477.000000
# 50%     25018.00000     255.000000       3.000000            2724.000000
# 75%     37506.00000     377.000000       4.000000            3974.000000
# max     50000.00000     500.000000       5.000000            5350.000000
#
#                  NPS  Customer Age        Latitude     Longituide
# count  250000.000000  250000.000000  250000.000000  250000.000000
# mean        4.991832      43.759228      42.400790     -81.648522
# std         3.166732      15.392075       7.214608      37.339110
# ...

# %%
df.isnull() #Aqui retorna se há valores nulos ou não
# Out:
#         Customer ID  Purchase Date  Product Category  Product Price  Quantity  \
# 0             False          False             False          False     False
# 1             False          False             False          False     False
# 2             False          False             False          False     False
# 3             False          False             False          False     False
# 4             False          False             False          False     False
# ...             ...            ...               ...            ...       ...
# 249995        False          False             False          False     False
# 249996        False          False             False          False     False
# 249997        False          False             False          False     False
# 249998        False          False             False          False     False
# 249999        False          False             False          False     False
#
# ...

# %%
df.dtypes
# Out:
# Customer ID                int64
# Purchase Date             object
# Product Category          object
# Product Price              int64
# Quantity                   int64
# Total Purchase Amount      int64
# NPS                        int64
# Customer Age               int64
# Gender                    object
# Source                    object
# Country                   object
# State                     object
# Latitude                 float64
# Longituide               float64
# dtype: object

# %%
df['Product Category'].value_counts()
# Out:
# Product Category
# Clothing       75052
# Books          74912
# Electronics    50185
# Home           49851
# Name: count, dtype: int64

# %%
df['Customer Age '].value_counts()
# Out:
# Customer Age
# 21    6010
# 18    5051
# 31    5036
# 58    4986
# 51    4983
# 70    4967
# 27    4918
# 41    4873
# 46    4851
# 49    4839
# 42    4836
# 56    4828
# 20    4810
# 43    4791
# 25    4790
# 60    4779
# 23    4761
# 34    4760
# 61    4759
# 28    4754
# 40    4751
# 30    4750
# 38    4746
# 19    4733
# 22    4725
# 68    4706
# 24    4685
# 55    4679
# 26    4676
# 63    4675
# 67    4674
# 39    4644
# 69    4626
# 29    4623
# 37    4615
# 45    4600
# 47    4581
# 65    4580
# 33    4573
# 64    4564
# 50    4552
# 66    4548
# 53    4536
# 44    4531
# 52    4521
# 62    4520
# 35    4515
# 36    4512
# 48    4463
# 54    4443
# 32    4438
# 59    4423
# 57    4410
# Name: count, dtype: int64

# %%
df['Purchase Date'].value_counts()
# Out:
# Purchase Date
# 12/03/2021    226
# 08/07/2022    226
# 04/07/2020    225
# 30/11/2022    223
# 18/08/2020    222
#              ...
# 22/12/2022    148
# 06/08/2021    148
# 26/09/2021    148
# 19/01/2022    147
# 15/09/2023     94
# Name: count, Length: 1354, dtype: int64

# %%
df['Product Price'].value_counts()
# Out:
# Product Price
# 100    583
# 28     576
# 324    572
# 187    565
# 119    563
#       ...
# 148    457
# 431    456
# 228    451
# 377    448
# 104    427
# Name: count, Length: 491, dtype: int64

# %%
df['NPS'].value_counts(2021)
# Out:
# NPS
# 1     0.092132
# 0     0.091452
# 6     0.091132
# 9     0.091108
# 2     0.091092
# 10    0.090912
# 5     0.090896
# 3     0.090388
# 8     0.090360
# 7     0.090332
# 4     0.090196
# Name: proportion, dtype: float64

# %%
print(df.columns)
# Out:
# Index(['Customer ID', 'Purchase Date', 'Product Category', 'Product Price',
#        'Quantity', 'Total Purchase Amount', 'NPS', 'Customer Age ', 'Gender',
#        'Source', 'Country', 'State', 'Latitude', 'Longituide'],
#       dtype='object')

# %%
df1 = df.copy()

# %%
df1 = df1.drop(['Country', 'State', 'Latitude', 'Longituide'], axis=1)
df1.head() #Apagando tabelas que não usarei.
# Out:
#    Customer ID Purchase Date Product Category  Product Price  Quantity  \
# 0        46251    08/09/2020      Electronics             12         3
# 1        46251    05/03/2022             Home            468         4
# 2        46251    23/05/2022             Home            288         2
# 3        46251    12/11/2020         Clothing            196         1
# 4        13593    27/11/2020             Home            449         1
#
#    Total Purchase Amount  NPS  Customer Age   Gender             Source
# 0                    740    7             20    Male  Instagram Campign
# 1                   2739    8             20    Male  Instagram Campign
# 2                   3196   10             20    Male                SEM
# 3                   3509    3             20    Male  Instagram Campign
# 4                   3452    3             20  Female  Instagram Campign

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   NPS                    250000 non-null  int64
#  7   Customer Age           250000 non-null  int64
#  8   Gender                 250000 non-null  object
#  9   Source                 250000 non-null  object
# dtypes: int64(6), object(4)
# memory usage: 19.1+ MB

# %%
#print('{:.0}'.format(df1['Customer Age '].count() / df1.shape[0]))
# Out:
# 1e+00

# %%
df1 = df1.dropna(subset=['Purchase Date', 'Product Category', 'Product Price', 'Quantity', 'Total Purchase Amount', 'NPS', 'Gender' ])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   NPS                    250000 non-null  int64
#  7   Customer Age           250000 non-null  int64
#  8   Gender                 250000 non-null  object
#  9   Source                 250000 non-null  object
# dtypes: int64(6), object(4)
# memory usage: 19.1+ MB

# %%
#Canal Ideial para vender os produtos
plt.figure(figsize=(10,7))
df1['Source'].value_counts().plot(kind='bar', color='g')
plt.xlabel('Canais')
plt.ylabel('Frequência')
plt.title('Canais Ideal para vender os produtos')
plt.legend('Canais mais utilizados')

# %%
# Publico Alvo
plt.figure(figsize=(10,7))
df1['Customer Age '].value_counts().plot(kind='bar', color='r')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.title('Tipo de publico')
plt.legend('Faixa Etária de Idade')

# %%
from datetime import date
produtos_mais_vendidos = df1['Product Category' ].value_counts()[:2022]
produtos_mais_vendidos
# Out:
# Product Category
# Clothing       75052
# Books          74912
# Electronics    50185
# Home           49851
# Name: count, dtype: int64

# %%
# Pergunta 1 - Prudtos mais vendidos em 2021
df1.loc[(df1['Product Category'] == 2021) & (df1['Purchase Date'])]
print(df1)
# Out:
#         Customer ID Purchase Date Product Category  Product Price  Quantity  \
# 0             46251    08/09/2020      Electronics             12         3
# 1             46251    05/03/2022             Home            468         4
# 2             46251    23/05/2022             Home            288         2
# 3             46251    12/11/2020         Clothing            196         1
# 4             13593    27/11/2020             Home            449         1
# ...             ...           ...              ...            ...       ...
# 249995        33308    10/08/2023         Clothing            279         2
# 249996        48835    23/11/2021             Home             27         1
# 249997        21019    02/07/2020             Home             17         5
# 249998        49234    30/12/2020            Books            398         2
# 249999        16971    13/03/2021      Electronics            425         4
#
# ...

# %%
# Pergunta 03
plt.figure(figsize=(9,7))
produtos_mais_vendidos.plot(kind='bar', color='r')
plt.title('Produtos Mais Vendidos')
plt.legend('Produtos')

# %%
from ast import main
# Pergunta 02:
plt.figure(figsize=(10,4))
df1['Product Price'].value_counts().head(20).plot(kind="bar")
plt.title('Valores')
# Out:
# Text(0.5, 1.0, 'Valores')

# %%
#plt.figure(figsize=(9,8))
##df2 = df1['Product Category']
#df3 = df1['Product Price']
#plt.bar(df2, df3, label='Categorias', color='b')
#plt.bar(df3, df2, label='Preços', color='r')
#plt.title('Categoria Mais Cara e Menos Cara')
#plt.show()

#df2 = ['Product Price']
#df1['Product Category'].value_counts().head(10).plot(kind='bar', color='r')
#df2['Product Price'].value_counts().head(10).plot(kind='bar', color='g')
#plt.xlabel('Categoria')
#plt.ylabel('Preço')

df1.plot(kind='scatter', x='Product Price', y='Product Category', title='Proutos mais Caros e mais Baratos')
plt.show()

# %%
# Pergunta 04
#plt.figure(figsize=(10,7))
#df['NPS'].value_counts().head(10).plot(kind='bar')
#df['Product Category'].value_counts().head(10).plot(kind='bar')
#plt.xlabel('Categoria')
#plt.ylabel('NPS')
#plt.title('Produto com Melhor e Pior NPS')

df1.plot(kind='scatter', x='Product Category', y='NPS', title='Produtos com Melhor e Pior NPS')
plt.show()

#aux = df1['Product Category'].plot(kind='hist', bins=20)
#ax.set_ylabel('Produtos com Melhor e Pior NPS')
